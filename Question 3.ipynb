# %%
#1 Create two lists with 20 random numbers in each list and display these two lists in the form of scatter plots:

import matplotlib.pyplot as plt
#create a figure and axis
fig , ax = plt.subplots()

x = [2, 4, 6, 6, 9, 2, 0, 2, 6, 1, 8, 4, 5, 9, 1, 2, 3, 7, 5, 8, 1, 3]
y = [7, 8, 2, 4, 6, 4, 9, 5, 9, 3, 6, 7, 2, 5, 6, 7, 1, 9, 4, 3, 6, 9]
ax.scatter(x, y)

# %%
#2. Display the same list in the form of a line chart
import matplotlib.pyplot as plt

# Create a figure and axis
fig, ax = plt.subplots()

# Data
x = [2, 4, 6, 6, 9, 2, 0, 2, 6, 1, 8, 4, 5, 9, 1, 2, 3, 7, 5, 8, 1, 3]
y = [7, 8, 2, 4, 6, 4, 9, 5, 9, 3, 6, 7, 2, 5, 6, 7, 1, 9, 4, 3, 6, 9]

# Line chart
ax.plot(x, y, linestyle='-')

# Add labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Line Chart')

# Show the plot
plt.show()

# %%
import seaborn as sns
help(sns)
# Out:
# Help on package seaborn:
#
# NAME
#     seaborn - # Import seaborn objects
#
# PACKAGE CONTENTS
#     _compat
#     _core (package)
#     _decorators
#     _docstrings
#     _marks (package)
#     _oldcore
#     _statistics
#     _stats (package)
#     _testing
#     algorithms
#     axisgrid
#     categorical
#     cm
#     colors (package)
#     distributions
#     external (package)
#     matrix
#     miscplot
#     objects
#     palettes
#     rcmod
#     regression
#     relational
#     utils
#     widgets
#
# DATA
#     crayons = {'Almond': '#EFDECD', 'Antique Brass': '#CD9575', 'Apricot':...
#     xkcd_rgb = {'acid green': '#8ffe09', 'adobe': '#bd6c48', 'algae': '#54...
#
# VERSION
#     0.12.2
#
# FILE
#     c:\users\ompan\anaconda3\lib\site-packages\seaborn\__init__.py

# %%
#3. Access table "Iris csv". Create a line chart for all columns except Species in one graph

import pandas as pd
import seaborn as sns
iris = pd.read_csv("C:\\Users\\ompan\\OneDrive\\Desktop\\PRACS SEM !\\ML git\\database\\Iris.csv")


# Exclude 'Species' column
columnstoplot = iris.columns[iris.columns != 'species']

# Create line chart for all columns except 'Species'
# Create line chart for all columns except 'Species' with increased figure size
plt.figure(figsize=(12, 6))
sns.lineplot(data=iris [columns_to_plot], dashes=False)
plt.title('Line Chart for Iris Dataset (excluding Species)')
plt.show()

# %%
#4. Create histogram for column "SepallengthCm of Iris table

# Create histogram for 'sepal_length'
plt.hist(iris['SepalLengthCm'], edgecolor='black')
plt.title('Histogram for Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
#5 Create barplot for column "SepalWidthcm" of Iris table
sns.barplot(x=iris.index, y='SepalWidthCm', data=iris)
plt.title('Bar Plot for Sepal Width')
plt.xlabel('Index')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
#6 Create horizontal bar plot for 'petallengthcm'

sns.barplot(x = 'PetalLengthCm', y=iris.index, data=iris)
plt.title('Horizontal Bar Plot for Petal Length')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Index')
plt.show()

# %%
#7 Create a DataFrame for the given data and display a pie plot:

import pandas as pd

# Create DataFrame for data
data = {'Tasks': [300, 500, 700], 'Task Type': ['Task Pending', 'Task Ongoing', 'Task Completed']}
df = pd.DataFrame(data)


# Display pie plot
df.set_index('Task Type')['Tasks'].plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Pie Plot for Task Types')
plt.ylabel('')
plt.show()

# %%
help()
# Out:
# Welcome to Python 3.11's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the internet at https://docs.python.org/3.11/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
