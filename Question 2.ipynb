# %%
# Task 1: Access table "US_violent_crime.csv"
import numpy as np
import pandas as pd
state=pd.read_csv("US_violent_crime.csv")

# %%
#i display categorical data of column 'state' trice
def some_func(x):
  return x*3
state.apply(some_func) 
state.apply(lambda n: n*3)
# Out:
#                                          State  Murder  Assault  UrbanPop  \
# 0                        AlabamaAlabamaAlabama    39.6      708       174
# 1                           AlaskaAlaskaAlaska    30.0      789       144
# 2                        ArizonaArizonaArizona    24.3      882       240
# 3                     ArkansasArkansasArkansas    26.4      570       150
# 4               CaliforniaCaliforniaCalifornia    27.0      828       273
# 5                     ColoradoColoradoColorado    23.7      612       234
# 6            ConnecticutConnecticutConnecticut     9.9      330       231
# 7                     DelawareDelawareDelaware    17.7      714       216
# 8                        FloridaFloridaFlorida    46.2     1005       240
# 9                        GeorgiaGeorgiaGeorgia    52.2      633       180
# 10                          HawaiiHawaiiHawaii    15.9      138       249
# 11                             IdahoIdahoIdaho     7.8      360       162
# ...

# %%
# 1.1 Display categorical data of column "state" trice
state.isnull()
# Out:
#     State  Murder  Assault  UrbanPop   Rape
# 0   False   False    False     False  False
# 1   False   False    False     False  False
# 2   False   False    False     False  False
# 3   False   False    False     False  False
# 4   False   False    False     False  False
# 5   False   False    False     False  False
# 6   False   False    False     False  False
# 7   False   False    False     False  False
# 8   False   False    False     False  False
# 9   False   False    False     False  False
# 10  False   False    False     False  False
# 11  False   False    False     False  False
# 12  False   False    False     False  False
# 13  False   False    False     False  False
# 14  False   False    False     False  False
# 15  False   False    False     False  False
# 16  False   False    False     False  False
# 17  False   False    False     False  False
# 18  False   False    False     False  False
# 19  False   False    False     False  False
# ...

# %%
# 1.2 Check any missing values in column 'State" and display sum
state.isnull().sum()
# Out:
# State       0
# Murder      0
# Assault     0
# UrbanPop    0
# Rape        0
# dtype: int64

# %%
# 1.3 Display record stored at 4th row and 3rd column.
state.iloc[4,3]
# Out:
# 91

# %%
#Sub Question 2

import numpy as np
import pandas as pd
data_df=pd.read_csv("airline_stats.csv")
data_df.describe()
# Out:
#        pct_carrier_delay  pct_atc_delay  pct_weather_delay
# count       33440.000000   33440.000000       33440.000000
# mean            7.041475       5.089962           0.684776
# std             4.497596       4.718647           1.073743
# min             0.000000       0.000000           0.000000
# 25%             4.145455       2.146565           0.000000
# 50%             6.356893       3.900000           0.316002
# 75%             9.140474       6.630238           0.935161
# max           100.000000     100.000000          33.333333

# %%
# 2.1 Check if any null data and display its sum in each column.
null_data = data_df.isnull().sum()
print(null_data)
# Out:
# pct_carrier_delay    28
# pct_atc_delay        28
# pct_weather_delay    28
# airline               0
# dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 5
#       2 null_data = data_df.isnull().sum()
#       3 print(null_data)
# ----> 5 help(isnull())
#
# NameError: name 'isnull' is not defined

# %%
# 2.2 Fill null values by its column mean value.
data_df.fillna(data_df.mean(), inplace=True)
# Out:
# C:\Users\ompan\AppData\Local\Temp\ipykernel_20056\3181550715.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_df.fillna(data_df.mean(), inplace=True)

# %%
# 2.3 Again check for null values in each column
null_values_after_fill =data_df.isnull().sum()
# Out:
# pct_carrier_delay    0
# pct_atc_delay        0
# pct_weather_delay    0
# airline              0
# dtype: int64
